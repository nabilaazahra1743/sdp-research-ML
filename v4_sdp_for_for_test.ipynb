# %%
import pandas as pd

# %%
datasdp = pd.read_csv('D:\AAAAKK SKRIPSWEETT\Bismillah Code Skripsi V2\Dataset\Data Mentah SDP.csv', delimiter=";")
datasdp.head()
# Out:
#                                                 file  \
# 0  C:\Users\HP\ck\jfreechart\src\test\java\org\jf...
# 1  C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 2  C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 3  C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 4  C:\Users\HP\ck\jfreechart\src\test\java\org\jf...
#
#                                                class   type  cbo  cboModified  \
# 0                     org.jfree.data.xy.XYSeriesTest  class    5            5
# 1  org.jfree.chart.labels.StandardPieSectionLabel...  class    5            9
# 2         org.jfree.chart.renderer.xy.VectorRenderer  class   15           17
# 3                  org.jfree.chart.axis.CategoryTick  class    5            7
# 4  org.jfree.chart.labels.StandardXYSeriesLabelGe...  class    6            6
#
#    fanin  fanout  wmc  dit  noc  ...  assignmentsQty  mathOperationsQty  \
# 0      0       5   37    1    0  ...              50                  0
# ...

# %%
print(datasdp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8924 entries, 0 to 8923
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   file                    8924 non-null   object
#  1   class                   8924 non-null   object
#  2   type                    8924 non-null   object
#  3   cbo                     8924 non-null   int64
#  4   cboModified             8924 non-null   int64
#  5   fanin                   8924 non-null   int64
#  6   fanout                  8924 non-null   int64
#  7   wmc                     8924 non-null   int64
#  8   dit                     8924 non-null   int64
#  9   noc                     8924 non-null   int64
#  10  rfc                     8924 non-null   int64
#  11  lcom                    8924 non-null   int64
#  12  lcom*                   8781 non-null   object
#  13  tcc                     6517 non-null   object
# ...

# %%
print(datasdp.describe())  # Summary statistics
# Out:
#                cbo  cboModified        fanin       fanout          wmc  \
# count  1048.000000  1048.000000  1048.000000  1048.000000  1048.000000
# mean      5.927481     9.093511     3.166031     5.927481    21.253817
# std       6.866477    11.922739     9.371313     6.866477    44.041750
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     3.000000     0.000000     2.000000     3.000000
# 50%       4.000000     6.000000     1.000000     4.000000     8.000000
# 75%       7.000000    11.000000     3.000000     7.000000    22.000000
# max      82.000000   195.000000   193.000000    82.000000   681.000000
#
#                dit          noc          rfc          lcom        lcom*  ...  \
# count  1048.000000  1048.000000  1048.000000   1048.000000  1041.000000  ...
# mean      1.589695     0.230916    17.969466    151.202290     0.319231  ...
# std       1.094210     1.281757    27.729782   1238.552228     0.362494  ...
# ...

# %%
print(datasdp[datasdp.isnull().any(axis=1)])
# Out:
#                                                    file  \
# 6     C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 8     C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 39    C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 40    C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# 50    C:\Users\HP\ck\jfreechart\src\main\java\org\jf...
# ...                                                 ...
# 8912  C:\Users\HP\ck\mockito\mockito-core\src\test\j...
# 8914  C:\Users\HP\ck\mockito\mockito-extensions\mock...
# 8917  C:\Users\HP\ck\mockito\mockito-core\src\main\j...
# 8919  C:\Users\HP\ck\mockito\mockito-core\src\main\j...
# 8921  C:\Users\HP\ck\mockito\mockito-core\src\testFi...
#
#                                                   class        type  cbo  \
# 6     org.jfree.chart.renderer.xy.DeviationRenderer$...  innerclass    2
# 8         org.jfree.data.resources.DataPackageResources       class    0
# ...

# %%
print(datasdp.isnull().sum().sum())
# Out:
# 4957
